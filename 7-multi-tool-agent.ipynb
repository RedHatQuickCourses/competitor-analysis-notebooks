# %% [markdown]
# # Multi-Tool Agent with LlamaStack
#
# This notebook demonstrates how to create an agent that can use **multiple tools** and let the LLM **automatically choose** the right tool based on the query.
#
# ## Tools Available:
# 1. **indian_bank_stock** - Fetch stock prices for Indian banks (HDFC, ICICI, SBI) via Yahoo Finance
# 2. **web_search** - Search the web for real-time information (gold prices, exchange rates, news) via Tavily
#
# ## Approach:
# We use LlamaStack's **Chat Completions API** with OpenAI-compatible function calling. The LLM decides which tool to use, and we execute it client-side.

# %%
# Install dependencies
# %pip install -q llama_stack_client==0.3.0 yfinance rich
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import yfinance as yf
import rich
from llama_stack_client import LlamaStackClient

# %%
# LlamaStack service URL (in-cluster)
LLAMASTACK_URL = "http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321"

# For access from Notebooks external to the cluster, use the route URL instead
# LLAMASTACK_URL = "https://llama-stack-ext-competitor-analysis.apps.ocp.sx7qw.sandbox2219.opentlc.com/"

# Tavily API key for web search
tavily_search_api_key = os.getenv('TAVILY_SEARCH_API_KEY', 'tvly-xxxxxxx')

# Initialize client with Tavily provider data
client = LlamaStackClient(
    base_url=LLAMASTACK_URL,
    provider_data={"tavily_search_api_key": tavily_search_api_key},
    timeout=300.0
)

# Get available model
models = client.models.list()
model_id = next(m.identifier for m in models if m.model_type == "llm")
print(f"Using model: {model_id}")
# Out:
# INFO:httpx:HTTP Request: GET http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/models "HTTP/1.1 200 OK"
# Using model: vllm-inference/granite-3-3-8b-instruct

# %% [markdown]
# ## Define Tool Schemas
#
# We define both tools using OpenAI-compatible function schemas. The LLM will see these definitions and decide which tool to call based on the user's query.

# %%
# Tool definitions using OpenAI-compatible function schema
TOOLS = [
    {
        "type": "function",
        "function": {
            "name": "indian_bank_stock",
            "description": "Get current stock price and financial data for Indian banks. Use for HDFC Bank, ICICI Bank, or State Bank of India (SBI) stock queries.",
            "parameters": {
                "type": "object",
                "properties": {
                    "ticker": {
                        "type": "string",
                        "description": "Stock ticker symbol: HDFCBANK.NS (HDFC Bank), ICICIBANK.NS (ICICI Bank), or SBIN.NS (SBI)",
                        "enum": ["HDFCBANK.NS", "ICICIBANK.NS", "SBIN.NS"]
                    }
                },
                "required": ["ticker"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "web_search",
            "description": "Search the web for real-time information. Use for gold prices, currency exchange rates, news, weather, or any current events.",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {
                        "type": "string",
                        "description": "The search query"
                    }
                },
                "required": ["query"]
            }
        }
    }
]

print("Tools registered:")
for tool in TOOLS:
    print(f"  - {tool['function']['name']}: {tool['function']['description'][:60]}...")
# Out:
# Tools registered:
#   - indian_bank_stock: Get current stock price and financial data for Indian banks....
#   - web_search: Search the web for real-time information. Use for gold price...

# %% [markdown]
# ## Tool Execution Functions
#
# These functions actually execute the tools when the LLM requests them.

# %%
def execute_indian_bank_stock(ticker: str) -> dict:
    """
    Execute the indian_bank_stock tool using Yahoo Finance API.
    """
    print(f"  📈 Fetching {ticker} from Yahoo Finance...")
    
    try:
        stock = yf.Ticker(ticker)
        info = stock.info
        
        current_price = info.get('currentPrice') or info.get('regularMarketPrice')
        previous_close = info.get('previousClose')
        
        result = {
            "ticker": ticker,
            "company": info.get('longName'),
            "current_price": current_price,
            "currency": "INR",
            "previous_close": previous_close,
            "day_change": round(current_price - previous_close, 2) if current_price and previous_close else None,
            "market_cap": info.get('marketCap'),
            "volume": info.get('volume')
        }
        
        print(f"  ✅ Got price: ₹{result['current_price']}")
        return result
        
    except Exception as e:
        return {"error": str(e), "ticker": ticker}


def execute_web_search(query: str) -> str:
    """
    Execute web search using LlamaStack's built-in Tavily integration.
    We use the Responses API which handles web_search server-side.
    """
    print(f"  🌐 Searching web for: {query}")
    
    response = client.responses.create(
        model=model_id,
        input=query,
        tools=[{"type": "web_search"}],
        stream=False
    )
    
    result = response.output_text
    print(f"  ✅ Got web search result")
    return result

# %% [markdown]
# ## Multi-Tool Agent
#
# The agent uses a simple loop:
# 1. Send query to LLM with all tool definitions
# 2. If LLM requests a tool → execute it and send result back
# 3. LLM generates final response using the tool output

# %%
def run_agent(query: str, verbose: bool = True) -> str:
    """
    Run the multi-tool agent. The LLM automatically chooses which tool to use.
    
    Args:
        query: User's question
        verbose: Print debug information
    
    Returns:
        The agent's final response
    """
    if verbose:
        print(f"\n{'='*60}")
        print(f"🤖 Query: {query}")
        print(f"{'='*60}")
    
    # Detailed system message with explicit instructions
    messages = [
        {
            "role": "system",
            "content": """You are a helpful financial assistant. You MUST use tools to answer questions - never make up data.

AVAILABLE TOOLS:
1. indian_bank_stock - Use this for stock prices of:
   - HDFC Bank → ticker: "HDFCBANK.NS"
   - ICICI Bank → ticker: "ICICIBANK.NS"  
   - State Bank of India (SBI) → ticker: "SBIN.NS"

2. web_search - Use this for:
   - Gold prices
   - Currency exchange rates (USD/INR, EUR/INR, etc.)
   - Any news or current events
   - Any other real-time information

INSTRUCTIONS:
- When asked about HDFC, ICICI, or SBI stock prices, call indian_bank_stock with the correct ticker
- When asked about gold, currencies, or news, call web_search with a clear query
- ALWAYS call a tool - never guess or make up prices
- After receiving tool results, summarize them clearly for the user"""
        },
        {"role": "user", "content": query}
    ]
    
    # Step 1: Ask LLM which tool to use
    if verbose:
        print(f"\n📤 Sending request to LLM with {len(TOOLS)} tools...")
    
    response = client.chat.completions.create(
        model=model_id,
        messages=messages,
        tools=TOOLS,
        tool_choice="required"  # Force tool use
    )
    
    # DEBUG: Print the RAW response
    if verbose:
        print(f"\n{'='*60}")
        print(f"🔍 DEBUG - RAW API RESPONSE:")
        print(f"{'='*60}")
        print(f"Response type: {type(response)}")
        print(f"Response object: {response}")
        print(f"\nChoices[0]:")
        print(f"  finish_reason: {response.choices[0].finish_reason}")
        print(f"  message type: {type(response.choices[0].message)}")
        print(f"  message: {response.choices[0].message}")
        print(f"{'='*60}")
    
    assistant_message = response.choices[0].message
    
    # DEBUG: Inspect message attributes
    if verbose:
        print(f"\n🔍 DEBUG - Message attributes:")
        for attr in dir(assistant_message):
            if not attr.startswith('_'):
                try:
                    val = getattr(assistant_message, attr)
                    if not callable(val):
                        print(f"   {attr}: {val}")
                except:
                    pass
    
    # Step 2: Check if LLM wants to call a tool
    if hasattr(assistant_message, 'tool_calls') and assistant_message.tool_calls:
        tool_call = assistant_message.tool_calls[0]
        
        if verbose:
            print(f"\n✅ Tool call detected!")
            print(f"   tool_call object: {tool_call}")
            print(f"   function.name: {tool_call.function.name}")
            print(f"   function.arguments: {tool_call.function.arguments}")
        
        func_name = tool_call.function.name
        func_args = json.loads(tool_call.function.arguments)
        
        print(f"\n🔧 LLM chose tool: {func_name}")
        print(f"   Arguments: {func_args}")
        
        # Step 3: Execute the tool
        if func_name == "indian_bank_stock":
            ticker = func_args.get("ticker", "HDFCBANK.NS")
            print(f"\n🚀 EXECUTING indian_bank_stock with ticker={ticker}")
            tool_result = execute_indian_bank_stock(ticker)
            tool_result_str = json.dumps(tool_result)
            print(f"\n📊 RAW TOOL RESULT: {tool_result_str}")
        elif func_name == "web_search":
            search_query = func_args.get("query", query)
            print(f"\n🚀 EXECUTING web_search with query={search_query}")
            return execute_web_search(search_query)
        else:
            tool_result_str = json.dumps({"error": f"Unknown tool: {func_name}"})
        
        # Step 4: Send tool result back to LLM for final response
        messages.append({
            "role": "assistant",
            "content": None,
            "tool_calls": [tool_call]
        })
        messages.append({
            "role": "tool",
            "tool_call_id": tool_call.id,
            "content": tool_result_str
        })
        
        print(f"\n📤 Sending tool result back to LLM for summary...")
        
        final_response = client.chat.completions.create(
            model=model_id,
            messages=messages
        )
        
        answer = final_response.choices[0].message.content
        print(f"\n✅ Final Answer: {answer}")
    else:
        # No tool call - LLM answered directly (shouldn't happen with tool_choice="required")
        print(f"\n⚠️ WARNING: No tool_calls detected! LLM answered directly.")
        answer = assistant_message.content
        print(f"\n❌ Direct answer (likely hallucinated): {answer}")
    
    return answer

# %% [markdown]
# ## Test: Stock Price Query
#
# The LLM should automatically choose `indian_bank_stock` tool.

# %%
# Test 1: Stock query - should use indian_bank_stock tool
run_agent("What's the current stock price of HDFC Bank?")
# Out:
# ============================================================
# 🤖 Query: What's the current stock price of HDFC Bank?
# ============================================================
#
# 📤 Sending request to LLM with 2 tools...
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/chat/completions "HTTP/1.1 200 OK"
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_computed_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# ============================================================
# 🔍 DEBUG - RAW API RESPONSE:
# ============================================================
# Response type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletion'>
# Response object: OpenAIChatCompletion(id='chatcmpl-ff695d80f8d74c8da60856079f641447', choices=[OpenAIChatCompletionChoice(finish_reason='stop', index=0, message=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-175b2bc91f064b5eb25d4e9fe40a26d4', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "HDFCBANK.NS"}', name='indian_bank_stock'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None), logprobs=None, stop_reason=None)], created=1767880698, model='granite-3-3-8b-instruct', object='chat.completion', usage=OpenAIChatCompletionUsage(completion_tokens=38, prompt_tokens=565, total_tokens=603, completion_tokens_details=None, prompt_tokens_details=None), service_tier=None, system_fingerprint=None, prompt_logprobs=None, kv_transfer_params=None, metrics=[{'trace_id': 'b739afc565b8b1977dafe7fc27f030ae', 'span_id': '586a620185d9010b', 'timestamp': '2026-01-08T13:58:20.040423Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'prompt_tokens', 'value': 565, 'unit': 'tokens'}, {'trace_id': 'b739afc565b8b1977dafe7fc27f030ae', 'span_id': '586a620185d9010b', 'timestamp': '2026-01-08T13:58:20.040447Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'completion_tokens', 'value': 38, 'unit': 'tokens'}, {'trace_id': 'b739afc565b8b1977dafe7fc27f030ae', 'span_id': '586a620185d9010b', 'timestamp': '2026-01-08T13:58:20.040452Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'total_tokens', 'value': 603, 'unit': 'tokens'}])
#
# Choices[0]:
#   finish_reason: stop
#   message type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam'>
#   message: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-175b2bc91f064b5eb25d4e9fe40a26d4', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "HDFCBANK.NS"}', name='indian_bank_stock'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None)
# ============================================================
#
# 🔍 DEBUG - Message attributes:
#    content:
#    model_computed_fields: {}
#    model_config: {'extra': 'allow', 'defer_build': True}
#    model_extra: {'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'reasoning_content': None}
#    model_fields: {'role': FieldInfo(annotation=Literal['assistant'], required=True), 'content': FieldInfo(annotation=Union[str, List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamContentUnionMember1], NoneType], required=False, default=None), 'name': FieldInfo(annotation=Union[str, NoneType], required=False, default=None), 'tool_calls': FieldInfo(annotation=Union[List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall], NoneType], required=False, default=None)}
#    model_fields_set: {'refusal', 'reasoning_content', 'content', 'annotations', 'audio', 'tool_calls', 'role', 'function_call'}
#    name: None
#    role: assistant
#    tool_calls: [OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-175b2bc91f064b5eb25d4e9fe40a26d4', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "HDFCBANK.NS"}', name='indian_bank_stock'), index=None)]
#
# ✅ Tool call detected!
#    tool_call object: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-175b2bc91f064b5eb25d4e9fe40a26d4', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "HDFCBANK.NS"}', name='indian_bank_stock'), index=None)
#    function.name: indian_bank_stock
#    function.arguments: {"ticker": "HDFCBANK.NS"}
#
# 🔧 LLM chose tool: indian_bank_stock
#    Arguments: {'ticker': 'HDFCBANK.NS'}
#
# 🚀 EXECUTING indian_bank_stock with ticker=HDFCBANK.NS
#   📈 Fetching HDFCBANK.NS from Yahoo Finance...
#   ✅ Got price: ₹946.7
#
# 📊 RAW TOOL RESULT: {"ticker": "HDFCBANK.NS", "company": "HDFC Bank Limited", "current_price": 946.7, "currency": "INR", "previous_close": 949.05, "day_change": -2.35, "market_cap": 14564542382080, "volume": 21927772}
#
# 📤 Sending tool result back to LLM for summary...
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Final Answer: The current stock price of HDFC Bank is around 946.7 INR.
# 'The current stock price of HDFC Bank is around 946.7 INR.'

# %%
# Test 2: Another stock query
run_agent("What is SBI's stock price today?")
# Out:
# ============================================================
# 🤖 Query: What is SBI's stock price today?
# ============================================================
#
# 📤 Sending request to LLM with 2 tools...
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/chat/completions "HTTP/1.1 200 OK"
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_computed_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# ============================================================
# 🔍 DEBUG - RAW API RESPONSE:
# ============================================================
# Response type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletion'>
# Response object: OpenAIChatCompletion(id='chatcmpl-ae89b7170e0c40e29219ca51db9bd153', choices=[OpenAIChatCompletionChoice(finish_reason='stop', index=0, message=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f09349795413429382f40454824981d2', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "SBIN.NS"}', name='indian_bank_stock'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None), logprobs=None, stop_reason=None)], created=1767880714, model='granite-3-3-8b-instruct', object='chat.completion', usage=OpenAIChatCompletionUsage(completion_tokens=37, prompt_tokens=563, total_tokens=600, completion_tokens_details=None, prompt_tokens_details=None), service_tier=None, system_fingerprint=None, prompt_logprobs=None, kv_transfer_params=None, metrics=[{'trace_id': 'b88ca4548456b7d49228ae0d14b78a5e', 'span_id': '0ef3526604f1ac63', 'timestamp': '2026-01-08T13:58:36.230471Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'prompt_tokens', 'value': 563, 'unit': 'tokens'}, {'trace_id': 'b88ca4548456b7d49228ae0d14b78a5e', 'span_id': '0ef3526604f1ac63', 'timestamp': '2026-01-08T13:58:36.230494Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'completion_tokens', 'value': 37, 'unit': 'tokens'}, {'trace_id': 'b88ca4548456b7d49228ae0d14b78a5e', 'span_id': '0ef3526604f1ac63', 'timestamp': '2026-01-08T13:58:36.230499Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'total_tokens', 'value': 600, 'unit': 'tokens'}])
#
# Choices[0]:
#   finish_reason: stop
#   message type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam'>
#   message: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f09349795413429382f40454824981d2', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "SBIN.NS"}', name='indian_bank_stock'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None)
# ============================================================
#
# 🔍 DEBUG - Message attributes:
#    content:
#    model_computed_fields: {}
#    model_config: {'extra': 'allow', 'defer_build': True}
#    model_extra: {'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'reasoning_content': None}
#    model_fields: {'role': FieldInfo(annotation=Literal['assistant'], required=True), 'content': FieldInfo(annotation=Union[str, List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamContentUnionMember1], NoneType], required=False, default=None), 'name': FieldInfo(annotation=Union[str, NoneType], required=False, default=None), 'tool_calls': FieldInfo(annotation=Union[List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall], NoneType], required=False, default=None)}
#    model_fields_set: {'refusal', 'reasoning_content', 'content', 'annotations', 'audio', 'tool_calls', 'role', 'function_call'}
#    name: None
#    role: assistant
#    tool_calls: [OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f09349795413429382f40454824981d2', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "SBIN.NS"}', name='indian_bank_stock'), index=None)]
#
# ✅ Tool call detected!
#    tool_call object: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f09349795413429382f40454824981d2', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"ticker": "SBIN.NS"}', name='indian_bank_stock'), index=None)
#    function.name: indian_bank_stock
#    function.arguments: {"ticker": "SBIN.NS"}
#
# 🔧 LLM chose tool: indian_bank_stock
#    Arguments: {'ticker': 'SBIN.NS'}
#
# 🚀 EXECUTING indian_bank_stock with ticker=SBIN.NS
#   📈 Fetching SBIN.NS from Yahoo Finance...
#   ✅ Got price: ₹998.0
#
# 📊 RAW TOOL RESULT: {"ticker": "SBIN.NS", "company": "State Bank of India", "current_price": 998.0, "currency": "INR", "previous_close": 1007.15, "day_change": -9.15, "market_cap": 9212156444672, "volume": 6852487}
#
# 📤 Sending tool result back to LLM for summary...
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/chat/completions "HTTP/1.1 200 OK"
# ✅ Final Answer: Today, the stock price of State Bank of India (SBIN.NS) is 998.00 INR. There was a day change of -9.15 INR from the previous close of 1007.15 INR. The market capital is approximately 92,121,564,467,200 INR with a trading volume of 6,852,487 shares.
# 'Today, the stock price of State Bank of India (SBIN.NS) is 998.00 INR. There was a day change of -9.15 INR from the previous close of 1007.15 INR. The market capital is approximately 92,121,564,467,200 INR with a trading volume of 6,852,487 shares.'

# %% [markdown]
# ## Test: Web Search Query
#
# The LLM should automatically choose `web_search` tool.

# %%
# Test 3: Web search - should use web_search tool
run_agent("What is the current gold price per ounce?")
# Out:
# ============================================================
# 🤖 Query: What is the current gold price per ounce?
# ============================================================
#
# 📤 Sending request to LLM with 2 tools...
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/chat/completions "HTTP/1.1 200 OK"
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_computed_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# ============================================================
# 🔍 DEBUG - RAW API RESPONSE:
# ============================================================
# Response type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletion'>
# Response object: OpenAIChatCompletion(id='chatcmpl-f9ffc8bc72824247a7888f580886852f', choices=[OpenAIChatCompletionChoice(finish_reason='stop', index=0, message=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-552ddded289a47a3b8c627b35682cd25', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "current gold price per ounce"}', name='web_search'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None), logprobs=None, stop_reason=None)], created=1767880737, model='granite-3-3-8b-instruct', object='chat.completion', usage=OpenAIChatCompletionUsage(completion_tokens=32, prompt_tokens=564, total_tokens=596, completion_tokens_details=None, prompt_tokens_details=None), service_tier=None, system_fingerprint=None, prompt_logprobs=None, kv_transfer_params=None, metrics=[{'trace_id': '71865bb6282ab9150286f84a55ee1dfd', 'span_id': 'a3b4d511f0b627e2', 'timestamp': '2026-01-08T13:58:58.345609Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'prompt_tokens', 'value': 564, 'unit': 'tokens'}, {'trace_id': '71865bb6282ab9150286f84a55ee1dfd', 'span_id': 'a3b4d511f0b627e2', 'timestamp': '2026-01-08T13:58:58.345632Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'completion_tokens', 'value': 32, 'unit': 'tokens'}, {'trace_id': '71865bb6282ab9150286f84a55ee1dfd', 'span_id': 'a3b4d511f0b627e2', 'timestamp': '2026-01-08T13:58:58.345636Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'total_tokens', 'value': 596, 'unit': 'tokens'}])
#
# Choices[0]:
#   finish_reason: stop
#   message type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam'>
#   message: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-552ddded289a47a3b8c627b35682cd25', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "current gold price per ounce"}', name='web_search'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None)
# ============================================================
#
# 🔍 DEBUG - Message attributes:
#    content:
#    model_computed_fields: {}
#    model_config: {'extra': 'allow', 'defer_build': True}
#    model_extra: {'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'reasoning_content': None}
#    model_fields: {'role': FieldInfo(annotation=Literal['assistant'], required=True), 'content': FieldInfo(annotation=Union[str, List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamContentUnionMember1], NoneType], required=False, default=None), 'name': FieldInfo(annotation=Union[str, NoneType], required=False, default=None), 'tool_calls': FieldInfo(annotation=Union[List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall], NoneType], required=False, default=None)}
#    model_fields_set: {'refusal', 'reasoning_content', 'content', 'annotations', 'audio', 'tool_calls', 'role', 'function_call'}
#    name: None
#    role: assistant
#    tool_calls: [OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-552ddded289a47a3b8c627b35682cd25', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "current gold price per ounce"}', name='web_search'), index=None)]
#
# ✅ Tool call detected!
#    tool_call object: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-552ddded289a47a3b8c627b35682cd25', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "current gold price per ounce"}', name='web_search'), index=None)
#    function.name: web_search
#    function.arguments: {"query": "current gold price per ounce"}
#
# 🔧 LLM chose tool: web_search
#    Arguments: {'query': 'current gold price per ounce'}
#
# 🚀 EXECUTING web_search with query=current gold price per ounce
#   🌐 Searching web for: current gold price per ounce
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/responses "HTTP/1.1 200 OK"
#   ✅ Got web search result
# "The current gold price per ounce is approximately:\n\n- $4,421.65 in USD as per [BullionVault](https://www.bullionvault.com/gold-price-chart.do) \n- Around $1,421.50 USD in [Gold Avenue](https://www.goldavenue.com/en/gold-price/usd/1-oz?srsltid=AfmBOoq_mdDC5FyAieG7Xvv80YxFahBE6ODSAPukODlp_VK88M41d6W0)\n- $4,425.40 USD according to [JM Bullion](https://www.jmbullion.com/charts/gold-price/) as of January 08, 2026 at 07:18 AM ET\n- $4,440 per ounce as mentioned in [Trading Economics](https://tradingeconomics.com/commodity/gold) according to a snapshot on the same day.\n\nKeep in mind prices fluctuate, and it's always a good idea to get the latest current market price from a reliable source."

# %%
# Test 4: Currency exchange rate
run_agent("What is the USD to INR exchange rate today?")
# Out:
# ============================================================
# 🤖 Query: What is the USD to INR exchange rate today?
# ============================================================
#
# 📤 Sending request to LLM with 2 tools...
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/chat/completions "HTTP/1.1 200 OK"
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_computed_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# /tmp/ipykernel_2088/3529673231.py:76: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   val = getattr(assistant_message, attr)
# ============================================================
# 🔍 DEBUG - RAW API RESPONSE:
# ============================================================
# Response type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletion'>
# Response object: OpenAIChatCompletion(id='chatcmpl-cdd5ae85e55345b796549cd5e6e13644', choices=[OpenAIChatCompletionChoice(finish_reason='stop', index=0, message=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f566ff3c3d214924a3b5b25b55770ff3', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "USD to INR exchange rate today"}', name='web_search'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None), logprobs=None, stop_reason=None)], created=1767880761, model='granite-3-3-8b-instruct', object='chat.completion', usage=OpenAIChatCompletionUsage(completion_tokens=37, prompt_tokens=565, total_tokens=602, completion_tokens_details=None, prompt_tokens_details=None), service_tier=None, system_fingerprint=None, prompt_logprobs=None, kv_transfer_params=None, metrics=[{'trace_id': '8b22c3fd962b80205c19e18944b5fdc5', 'span_id': '1b25af92feb1bf79', 'timestamp': '2026-01-08T13:59:22.645177Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'prompt_tokens', 'value': 565, 'unit': 'tokens'}, {'trace_id': '8b22c3fd962b80205c19e18944b5fdc5', 'span_id': '1b25af92feb1bf79', 'timestamp': '2026-01-08T13:59:22.645228Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'completion_tokens', 'value': 37, 'unit': 'tokens'}, {'trace_id': '8b22c3fd962b80205c19e18944b5fdc5', 'span_id': '1b25af92feb1bf79', 'timestamp': '2026-01-08T13:59:22.645238Z', 'attributes': {'model_id': 'vllm-inference/granite-3-3-8b-instruct', 'provider_id': 'vllm-inference'}, 'type': 'metric', 'metric': 'total_tokens', 'value': 602, 'unit': 'tokens'}])
#
# Choices[0]:
#   finish_reason: stop
#   message type: <class 'llama_stack_client.types.chat.completion_create_response.OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam'>
#   message: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParam(role='assistant', content='', name=None, tool_calls=[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f566ff3c3d214924a3b5b25b55770ff3', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "USD to INR exchange rate today"}', name='web_search'), index=None)], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None)
# ============================================================
#
# 🔍 DEBUG - Message attributes:
#    content:
#    model_computed_fields: {}
#    model_config: {'extra': 'allow', 'defer_build': True}
#    model_extra: {'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'reasoning_content': None}
#    model_fields: {'role': FieldInfo(annotation=Literal['assistant'], required=True), 'content': FieldInfo(annotation=Union[str, List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamContentUnionMember1], NoneType], required=False, default=None), 'name': FieldInfo(annotation=Union[str, NoneType], required=False, default=None), 'tool_calls': FieldInfo(annotation=Union[List[OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall], NoneType], required=False, default=None)}
#    model_fields_set: {'refusal', 'reasoning_content', 'content', 'annotations', 'audio', 'tool_calls', 'role', 'function_call'}
#    name: None
#    role: assistant
#    tool_calls: [OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f566ff3c3d214924a3b5b25b55770ff3', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "USD to INR exchange rate today"}', name='web_search'), index=None)]
#
# ✅ Tool call detected!
#    tool_call object: OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCall(type='function', id='chatcmpl-tool-f566ff3c3d214924a3b5b25b55770ff3', function=OpenAIChatCompletionChoiceMessageOpenAIAssistantMessageParamToolCallFunction(arguments='{"query": "USD to INR exchange rate today"}', name='web_search'), index=None)
#    function.name: web_search
#    function.arguments: {"query": "USD to INR exchange rate today"}
#
# 🔧 LLM chose tool: web_search
#    Arguments: {'query': 'USD to INR exchange rate today'}
#
# 🚀 EXECUTING web_search with query=USD to INR exchange rate today
#   🌐 Searching web for: USD to INR exchange rate today
# INFO:httpx:HTTP Request: POST http://llama-stack-dist-service.competitor-analysis.svc.cluster.local:8321/v1/responses "HTTP/1.1 200 OK"
#   ✅ Got web search result
# "Today, the USD to INR exchange rate stands at approximately INR 84.27 INR per 1 US dollar. Here are a few sources with updates on this rate:\n\n1. [USD to INR - Today's Best US Dollar to Rupee Exchange Rate](https://www.compareremit.com/todays-best-dollar-to-rupee-exchange-rate/) states it at INR 84.27 for 1 US dollar, with a note of continual dollar strength against the Indian rupee.\n\n2. [US dollars to Indian rupees Exchange Rate - Convert USD/INR - Wise](https://wise.com/us/currency-converter/usd-to-inr-rate) lists: 1 USD = 89.84 INR, 5 USD = 449.18 INR, 10 USD = 898.36 INR, and 20 USD = 1,796.72 INR.\n\n3. [1 USD to INR - US Dollars to Indian Rupees Exchange Rate - Xe](https://xe.com/en-us/currencyconverter/convert/?Amount=1&From=USD&To=INR) shows 1 USD is equivalent to 89.85 INR.\n\n4. [USD to INR Exchange Rate - Bloomberg.com](https://www.bloomberg.com/quote/USDINR:CUR) provides transaction details for the last open, previous close, YTD return, day range, and the 52-week range. The previous closing rate was 89.8862.\n\n5. [USD to INR | Convert US Dollar to Indian Rupee - Western Union](https://www.westernunion.com/us/en/currency-converter/usd-to-inr-rate.html) offers currency conversion with commentary on sending USD to receive INR via Western Union.\n\nPlease note exchange rates fluctuate, and these rates apply at the time of this response's knowledge cutoff. For the most current rates, please verify with the source or use a real-time currency converter."
